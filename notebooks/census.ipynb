# %%
import os 
os.chdir("..")

# %%
import polars as pl
from CensusForge import CensusAPI

capi = CensusAPI()

# %%
capi.url

# %%
capi.query(
    dataset="acs-acs5-profile",
    params_list=["DP03_0051E","DP03_0052E"],
    year=2030,
    extra="&for=county"
)

# %%
capi.get_variable_id(name=)

# %%
capi.conn.execute(
    """ 
    SELECT * FROM sqlite_db.variable_interm LIMIT(10);
    """
).df()
