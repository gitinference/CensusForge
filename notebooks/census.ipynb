# %%
import os 
os.chdir("..")

# %%
from CensusForge import CensusAPI
import requests

capi = CensusAPI()

# %%
df = capi.query(
    dataset="acs-acs5-pumspr",
    params_list=["ACCESSINET","ACR"],
    year=2021,
    extra="&for=state"
)

# %%
df

# %%
r = requests.get(url="https://api.census.gov/data/2021/acs/acs5/pumspr?get=ACCESSINET,ACR&for=state")

# %%
import numpy as np

# %%
pd.DataFrame(np.array(r.json()))

# %%
capi.url
